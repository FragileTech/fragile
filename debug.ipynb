# %%
from mathster.core.raw_data import RawDocumentSection

# %%
dir(RawDefinition)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dir(RawDefinition)
#
# NameError: name 'RawDefinition' is not defined

# %%
RawDocumentSection.model_json_schema()
# Out:
# {'$defs': {'RawAxiom': {'description': 'Direct transcription of an axiom block.\n\nAxioms in the Fragile framework have a multi-part structure:\n- Core assumption (the fundamental claim)\n- Parameters (mathematical objects used in the axiom)\n- Condition (formal statement of when the axiom applies)\n- Failure mode analysis (optional - what happens if violated)\n\nThe LLM should extract all parts verbatim, leaving fields empty if not present.',
#    'properties': {'source': {'$ref': '#/$defs/SourceLocation',
#      'description': 'Source location metadata for this extracted entity.'},
#     'full_text': {'description': 'Full verbatim text content of this entity.',
#      'title': 'Full Text',
#      'type': 'string'},
#     'label': {'description': "Unique axiom label (e.g., 'axiom-bounded-diameter', 'def-axiom-reward-regularity'). If the concept has no assigned label then we should create one for it.",
#      'pattern': '^(axiom-|ax-|def-axiom-)[a-z0-9-]+$',
#      'title': 'Label',
# ...
