# %%
from mathster.core.raw_data import RawDefinition
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mathster.core.raw_data import RawDefinition
#
# File ~/fragile/src/mathster/__init__.py:24
#      21     core_all = []  # Handle missing __all__
#      23 # Import LLM pipeline modules
# ---> 24 from mathster.llm import *  # noqa: F403
#      25 try:
#      26     from mathster.llm import __all__ as llm_all
#
# File ~/fragile/src/mathster/llm/__init__.py:26
#       1 """
#       2 LLM Interface for Mathematical Paper Extraction.
#       3
#    (...)
#      23     end LLMInterface
#      24 """
# ---> 26 from mathster.llm.document_container import (
#      27     EnrichedEntities,
#      28     MathematicalDocument,
#      29 )
#      30 from mathster.llm.llm_interface import (
#      31     call_batch_extraction_llm,
#      32     call_main_extraction_llm,
#    (...)
# ...

# %%
RawDefinition.label
